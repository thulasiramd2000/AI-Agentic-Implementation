# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os
openai_api_key = os.getenv("OPENAI_API_KEY")

if openai_api_key:
    print(f"OpenAI API key loaded successfully. It is {openai_api_key[:8]}.")
else:
    print("OpenAI API key not found. Please set the OPENAI_API_KEY environment variable.")
# Out:
# OpenAI API key loaded successfully. It is sk-proj-.

# %%
from openai import OpenAI

# %%
openai=OpenAI()

# %%
messages=[
    {"role": "user", "content": "Tell me a tech joke"},]

# %%
response = openai.chat.completions.create(model="gpt-5.4-nano",messages=messages)
print(response.choices[0].message.content)
# Out:
# Why do programmers prefer dark mode?
# Because light attracts bugs. 😄

# %%
question= "tell me a clear way to get placed in MAANG Companies. Respond only with one question"
messages=[
    {"role": "user", "content": question},]

# %%
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
question=(response.choices[0].message.content)
print(question)
# Out:
# What specific skills or experiences do you currently possess that align with the job requirements of MAANG companies?

# %%
messages=[
    {"role": "system", "content": question},]
messages
# Out:
# [{'role': 'system',
#   'content': 'What specific skills or experiences do you currently possess that align with the job requirements of MAANG companies?'}]

# %%
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
answer=(response.choices[0].message.content)
print(answer)
# Out:
# To align with the job requirements of MAANG (Meta, Amazon, Apple, Netflix, Google) companies, you would typically need to possess a combination of technical skills, experience, and soft skills. Here’s how you might frame your qualifications:
#
# 1. **Technical Skills**:
#    - **Programming Languages**: Proficiency in languages commonly used in the industry such as Python, Java, C++, or JavaScript.
#    - **Data Structures and Algorithms**: Strong understanding and practical experience in implementing data structures and algorithms, which is crucial for technical interviews.
#    - **Cloud Computing**: Familiarity with cloud platforms like AWS, Google Cloud, or Azure can be advantageous, especially with companies like Amazon and Google.
#    - **Software Development Lifecycle**: Experience in Agile methodologies and knowledge of version control systems like Git.
#    - **Machine Learning / AI**: Understanding of machine learning concepts and libraries (e.g., TensorFlow, Scikit-Learn) may be beneficial, particularly for data-centric roles.
#
# 2. **Experience**:
#    - **Internships**: Previous internships or co-op positions at tech companies or startups that showcase relevant projects and skills.
#    - **Projects**: A portfolio of personal or academic projects that demonstrate practical application of your skills—could include open-source contributions, hackathon projects, or coursework.
#    - **Industry Experience**: Work experience, even if not directly related to technology, demonstrating analytical and problem-solving skills can also be relevant.
#
# 3. **Soft Skills**:
#    - **Communication**: Ability to articulate complex ideas clearly and effectively, which is critical in collaborative environments.
#    - **Problem-Solving**: Strong analytical thinking and a track record of identifying and addressing challenges and inefficiencies.
#    - **Team Collaboration**: Experience working in teams, showing flexibility and open-mindedness in diverse group settings.
#
# 4. **Cultural Fit**:
#    - **Adaptability**: Demonstrating an ability to learn quickly and adapt to changing technologies or business contexts.
#    - **Innovation**: A track record of proposing new ideas or solutions that align with the innovative cultures of MAANG companies.
#
# 5. **Educational Background**:
#    - A degree in Computer Science, Engineering, or a related field (or equivalent experiences) may be relevant.
#
# When framing your skills and experiences, tailor your narrative to the specific role you are applying for, emphasizing aspects that resonate with the company’s values and the job description.
