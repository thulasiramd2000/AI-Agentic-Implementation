# %%
# Imports and environment first, all in one place

from dotenv import load_dotenv
from IPython.display import Image, display
from pydantic import BaseModel, Field
from langchain.agents import create_agent
from langchain.agents.middleware import wrap_tool_call
from langchain_core.tools import tool
from langgraph.checkpoint.memory import MemorySaver
from langchain_mcp_adapters.client import MultiServerMCPClient

load_dotenv(override=True)
# Out:
# True

# %%
@tool
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always winter in {city}!"

agent = create_agent(
    model="openai:gpt-5.4-mini",
    tools=[get_weather],
    system_prompt="You are a helpful assistant that can use tools to answer questions.",)

response = agent.invoke({"messages": [{"role": "user", "content": "What is the weather like in New York City today?"}]})
result= agent.invoke({"messages": [{"role": "user", "content": "What is MVP?"}]})
print(response["messages"][-1].content)
print(result["messages"][-1].content)
# Out:
# The weather in New York City today is: **“It’s always winter in New York City!”**
# “MVP” can mean a few different things, but the most common is:
#
# **Minimum Viable Product** — the simplest version of a product that still solves the core problem for users and lets you test the idea with real feedback.
#
# Example:
# If you’re building a food-delivery app, the MVP might only include:
# - browsing restaurants
# - placing an order
# - basic payment
#
# It would **not** include extra features like rewards, reviews, or advanced filters yet.
#
# If you want, I can also explain other meanings of **MVP** like **Most Valuable Player**.

# %% [markdown]
# ## LangChain Agents — `create_agent` and Model Strings
#
# - **`from langchain.agents import create_agent`** — imports the prebuilt agent constructor from LangChain's unified agents API; builds a ready-to-run ReAct-style agent graph for you, instead of hand-wiring `StateGraph` + nodes + edges like we did with LangGraph.
# - **`model="openai:gpt-5.4-mini"`** — model is passed as a `"provider:model_name"` **string**, not an instantiated `ChatOpenAI(...)` object. `create_agent` resolves the string internally (same convention as `init_chat_model`) and constructs the right provider class for you.
# - Why a string instead of `ChatOpenAI(model=...)` directly: it's provider-agnostic shorthand — swapping providers is just editing the prefix, e.g. `"anthropic:claude-opus-5"`, without importing a different class.
# - Trade-off: less direct control over provider-specific kwargs (`temperature`, `max_tokens`, etc.) unless passed separately — for fine-grained config, you can still pass an already-instantiated model object instead of a string.

# %%
aresult= await agent.ainvoke({"messages": [{"role": "user", "content": "What does async and ainvoke have in common?"}]})
print(aresult["messages"][-1].content)
# Out:
# `async` and `ainvoke` have in common that they both relate to **asynchronous execution**.
#
# - **`async`** is a language feature (in Python/JavaScript, etc.) used to define functions that can run without blocking.
# - **`ainvoke`** is typically an async method name meaning “async invoke,” used in libraries to call something asynchronously.
#
# So the common idea is:
# - they both support **non-blocking, awaitable operations**
# - they both are used when you want to **perform work concurrently or wait on I/O without stopping the program**
#
# If you want, I can also explain the difference between `async`, `await`, `invoke`, and `ainvoke` in Python or in LangChain specifically.
# /var/folders/9z/h9t5hsq11tx6fc2xvtkdbs5h0000gq/T/ipykernel_40119/4102391066.py:1: RuntimeWarning: coroutine 'Pregel.ainvoke' was never awaited
#   aresult= await agent.ainvoke({"messages": [{"role": "user", "content": "What does async and ainvoke have in common?"}]})
# ...
